# %%
import numpy as nu
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\Lenovo\Desktop\python with data science\project\cust_satisfaction.csv')

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      103904 non-null  object
#  1   Customer Type               103904 non-null  object
#  2   Type of Travel              103904 non-null  object
#  3   Class                       103904 non-null  object
#  4   satisfaction                103904 non-null  object
#  5   Age                         103904 non-null  int64
#  6   Flight Distance             103904 non-null  int64
#  7   Inflight entertainment      103904 non-null  int64
#  8   Baggage handling            103904 non-null  int64
#  9   Cleanliness                 103904 non-null  int64
#  10  Departure Delay in Minutes  103904 non-null  int64
#  11  Arrival Delay in Minutes    103594 non-null  float64
# dtypes: float64(1), int64(6), object(5)
# ...

# %%
df.describe()
# Out:
#                  Age  Flight Distance  Inflight entertainment  \
# count  103904.000000    103904.000000           103904.000000
# mean       39.379706      1189.448375                3.358158
# std        15.114964       997.147281                1.332991
# min         7.000000        31.000000                0.000000
# 25%        27.000000       414.000000                2.000000
# 50%        40.000000       843.000000                4.000000
# 75%        51.000000      1743.000000                4.000000
# max        85.000000      4983.000000                5.000000
#
#        Baggage handling    Cleanliness  Departure Delay in Minutes  \
# count     103904.000000  103904.000000               103904.000000
# mean           3.631833       3.286351                   14.815618
# std            1.180903       1.312273                   38.230901
# min            1.000000       0.000000                    0.000000
# 25%            3.000000       2.000000                    0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Gender                          0
# Customer Type                   0
# Type of Travel                  0
# Class                           0
# satisfaction                    0
# Age                             0
# Flight Distance                 0
# Inflight entertainment          0
# Baggage handling                0
# Cleanliness                     0
# Departure Delay in Minutes      0
# Arrival Delay in Minutes      310
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
#df.isnull().sum()
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df.duplicated().sum()
# Out:
# 172

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
df['Customer Type'].unique()
# Out:
# array(['Loyal Customer', 'disloyal Customer'], dtype=object)

# %%
df['Type of Travel'].unique()
# Out:
# array(['Personal Travel', 'Business travel'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Class'].unique()
# Out:
# array(['Eco Plus', 'Business', 'Eco'], dtype=object)

# %%
df['satisfaction'].unique()
# Out:
# array(['neutral or dissatisfied', 'satisfied'], dtype=object)

# %%
df['Age'].unique()
# Out:
# array([13, 25, 26, 61, 47, 52, 41, 20, 24, 12, 53, 33, 45, 38,  9, 17, 43,
#        58, 23, 57, 49, 36, 22, 31, 15, 35, 67, 37, 40, 34, 39, 50, 29, 54,
#        21, 28, 27, 69, 60, 48, 59, 46, 30, 66, 64, 44, 51, 32, 19, 42, 16,
#        11, 62,  8, 56, 68, 55, 18, 65, 72, 70, 63, 10,  7, 14, 80, 74, 71,
#        85, 73, 76, 77, 75, 79, 78], dtype=int64)

# %%
df['Flight Distance'].unique()
# Out:
# array([ 460,  235, 1142, ...,  974, 1479,  400], dtype=int64)

# %%
df['Inflight entertainment'].unique()
# Out:
# array([5, 1, 2, 3, 4, 0], dtype=int64)

# %%
df['Baggage handling'].unique()
# Out:
# array([4, 3, 5, 1, 2], dtype=int64)

# %%
#covert object data in numerical
dt={'Loyal Customer':1,'disloyal Customer':0}
dt.keys()
dt.values()
df['Customer Type']=df['Customer Type'].map(dt)

# %%
df['Customer Type'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df
# Out:
#         Gender  Customer Type   Type of Travel     Class  \
# 0         Male              1  Personal Travel  Eco Plus
# 1         Male              0  Business travel  Business
# 2       Female              1  Business travel  Business
# 3       Female              1  Business travel  Business
# 4         Male              1  Business travel  Business
# ...        ...            ...              ...       ...
# 103899  Female              0  Business travel       Eco
# 103900    Male              1  Business travel  Business
# 103901    Male              0  Business travel  Business
# 103902  Female              0  Business travel       Eco
# 103903    Male              1  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# 1       neutral or dissatisfied   25              235                       1
# ...

# %%
dt1={'Male':1,'Female': 0}
df['Gender']=df['Gender'].map(dt1)

# %%
df['Gender'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df
# Out:
#         Gender  Customer Type   Type of Travel     Class  \
# 0            1              1  Personal Travel  Eco Plus
# 1            1              0  Business travel  Business
# 2            0              1  Business travel  Business
# 3            0              1  Business travel  Business
# 4            1              1  Business travel  Business
# ...        ...            ...              ...       ...
# 103899       0              0  Business travel       Eco
# 103900       1              1  Business travel  Business
# 103901       1              0  Business travel  Business
# 103902       0              0  Business travel       Eco
# 103903       1              1  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# 1       neutral or dissatisfied   25              235                       1
# ...

# %%
dt2={'Personal Travel':0,'Business travel':1}
df['Type of Travel']=df['Type of Travel'].map(dt2)

# %%
dt3={'Eco Plus':0,'Business':1,'Eco':2}
df['Class']=df['Class'].map(dt3)

# %%
dt4={'neutral or dissatisfied':0,'satisfied':1}
df['satisfaction']=df['satisfaction'].map(dt4)

# %%
df['Class'].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
df
# Out:
#         Gender  Customer Type  Type of Travel  Class  satisfaction  Age  \
# 0            1              1               0      0             0   13
# 1            1              0               1      1             0   25
# 2            0              1               1      1             1   26
# 3            0              1               1      1             0   25
# 4            1              1               1      1             1   61
# ...        ...            ...             ...    ...           ...  ...
# 103899       0              0               1      2             0   23
# 103900       1              1               1      1             1   49
# 103901       1              0               1      1             0   30
# 103902       0              0               1      2             0   22
# 103903       1              1               1      1             0   27
#
#         Flight Distance  Inflight entertainment  Baggage handling  \
# ...

# %%
x=df.drop('Customer Type',axis=1)
y=df[['Customer Type']]
y # dependent
# Out:
#         Customer Type
# 0                   1
# 1                   0
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 103899              0
# 103900              1
# 103901              0
# 103902              0
# 103903              1
#
# [103422 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape,x_test.shape,y_test.shape,y_train.shape
# Out:
# ((82737, 11), (20685, 11), (20685, 1), (82737, 1))

# %%
x_train.head()
# Out:
#        Gender  Type of Travel  Class  satisfaction  Age  Flight Distance  \
# 71834       0               1      2             0   50              179
# 76517       1               0      2             0   21             1120
# 29502       1               1      1             1   48             3403
# 7185        1               1      1             0   56             1721
# 31081       0               1      2             1   52              933
#
#        Inflight entertainment  Baggage handling  Cleanliness  \
# 71834                       5                 4            5
# 76517                       1                 4            1
# 29502                       5                 5            4
# 7185                        2                 2            3
# 31081                       5                 5            1
#
#        Departure Delay in Minutes  Arrival Delay in Minutes
# 71834                          24                      17.0
# ...

# %%
y_train.head()
# Out:
#        Customer Type
# 71834              0
# 76517              1
# 29502              1
# 7185               1
# 31081              1

# %%
x_test
# Out:
#        Gender  Type of Travel  Class  satisfaction  Age  Flight Distance  \
# 40794       1               1      1             1   38             2623
# 28574       0               1      1             1   50             1617
# 4920        1               1      0             0   72              270
# 71169       0               1      1             1   45             1998
# 67168       1               1      1             1   39             2153
# ...       ...             ...    ...           ...  ...              ...
# 78398       0               1      1             1   22              937
# 47803       1               1      2             1   47              956
# 69942       0               1      1             0   25             1576
# 6464        0               0      2             0   24              622
# 49721       0               0      2             0   56              821
#
#        Inflight entertainment  Baggage handling  Cleanliness  \
# ...

# %%
y_test
# Out:
#        Customer Type
# 40794              1
# 28574              1
# 4920               1
# 71169              1
# 67168              1
# ...              ...
# 78398              0
# 47803              1
# 69942              1
# 6464               1
# 49721              1
#
# [20685 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("training score: -",lr.score(x_train,y_train))
# Out:
# training score: - 0.3808251779429489

# %%
lr.predict(x_test)
# Out:
# array([[1.02129721],
#        [0.90765494],
#        [0.75614458],
#        ...,
#        [0.49432801],
#        [0.82564403],
#        [1.11569739]])

# %%
pred=lr.predict(x_test)

# %%
pred
# Out:
# array([[1.02129721],
#        [0.90765494],
#        [0.75614458],
#        ...,
#        [0.49432801],
#        [0.82564403],
#        [1.11569739]])

# %%
x_test.shape
# Out:
# (20685, 11)

# %%
from sklearn.metrics import  mean_squared_error, mean_absolute_error

# %%
print("mse:-",mean_squared_error(y_test,pred))
# Out:
# mse:- 0.0921153740471392

# %%
from sklearn.metrics import   mean_absolute_error   #mae

# %%
print(mean_absolute_error(y_test,pred))
# Out:
# 0.23633487119749

# %%
from sklearn.metrics import mean_squared_error        #rmse
import math
import numpy as np

# %%
print("rmse" ,math.sqrt(mean_squared_error(y_test,pred)))
# Out:
# rmse 0.3035051466567564

# %%
pred,y_test
# Out:
# (array([[1.02129721],
#         [0.90765494],
#         [0.75614458],
#         ...,
#         [0.49432801],
#         [0.82564403],
#         [1.11569739]]),
#         Customer Type
#  40794              1
#  28574              1
#  4920               1
#  71169              1
#  67168              1
#  ...              ...
#  78398              0
#  47803              1
#  69942              1
#  6464               1
#  49721              1
#
#  [20685 rows x 1 columns])

# %%
y_test
# Out:
#        Customer Type
# 40794              1
# 28574              1
# 4920               1
# 71169              1
# 67168              1
# ...              ...
# 78398              0
# 47803              1
# 69942              1
# 6464               1
# 49721              1
#
# [20685 rows x 1 columns]

# %%
# confusion matrix
from sklearn.metrics import confusion_matrix,f1_score,recall_score,precision_score

# %%
pred=(pred>0.5).astype(int).ravel()  #0.5 threshold value which we fix in i dim   classification problem

# %%
y_test=(y_test>0.5).astype(int) #0.5 threshold value which we fix in i dim   classification problem

# %%
y_test
# Out:
#        Customer Type
# 40794              1
# 28574              1
# 4920               1
# 71169              1
# 67168              1
# ...              ...
# 78398              0
# 47803              1
# 69942              1
# 6464               1
# 49721              1
#
# [20685 rows x 1 columns]

# %%
pred
# Out:
# array([1, 1, 1, ..., 0, 1, 1])

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[ 2040,  1669],
#        [  637, 16339]], dtype=int64)

# %%
y   #precision_score(y_test.pred)
# Out:
#         Customer Type
# 0                   1
# 1                   0
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 103899              0
# 103900              1
# 103901              0
# 103902              0
# 103903              1
#
# [103422 rows x 1 columns]

# %%
precision_score(y_test,pred)
# Out:
# 0.9073189693469569

# %%
recall_score(y_test,pred)
# Out:
# 0.9624764373232799

# %%
f1_score(y_test,pred)
# Out:
# 0.9340841527555453

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cm=confusion_matrix(y_test,pred)

# %%
cm
# Out:
# array([[ 2040,  1669],
#        [  637, 16339]], dtype=int64)

# %%
y_test
# Out:
#        Customer Type
# 40794              1
# 28574              1
# 4920               1
# 71169              1
# 67168              1
# ...              ...
# 78398              0
# 47803              1
# 69942              1
# 6464               1
# 49721              1
#
# [20685 rows x 1 columns]

# %%
pred
# Out:
# array([1, 1, 1, ..., 0, 1, 1])

# %%
print("confusion matrix :-",confusion_matrix(y_test,pred))
print("precision score :-",precision_score(y_test,pred))
print("recall score :-",recall_score(y_test,pred))
print("f1score score :-",f1_score(y_test,pred))
# Out:
# confusion matrix :- [[ 2040  1669]
#  [  637 16339]]
# precision score :- 0.9073189693469569
# recall score :- 0.9624764373232799
# f1score score :- 0.9340841527555453

# %%
sns.heatmap(cm,annot=True,cmap="Blues",fmt="d")
plt.title('confusion matrix')
plt.xlabel("predicted")
plt.ylabel("actual")
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt_obj=DecisionTreeClassifier(criterion="entropy")

# %%
dt_obj.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
dt_obj.score(x_train,y_train)
# Out:
# 0.9999153945634964

# %%
pred=dt_obj.predict(x_test)

# %%
import pandas as pd

# %%
pred=pd.DataFrame(pred)

# %%
y_test
# Out:
#        Customer Type
# 40794              1
# 28574              1
# 4920               1
# 71169              1
# 67168              1
# ...              ...
# 78398              0
# 47803              1
# 69942              1
# 6464               1
# 49721              1
#
# [20685 rows x 1 columns]

# %%
pred
# Out:
#        0
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
# ...   ..
# 20680  1
# 20681  1
# 20682  1
# 20683  1
# 20684  1
#
# [20685 rows x 1 columns]

# %%
pd.concat([pred,y_test],axis=1)
# Out:
#          0  Customer Type
# 0      1.0            NaN
# 1      1.0            NaN
# 2      1.0            NaN
# 3      1.0            NaN
# 4      1.0            NaN
# ...    ...            ...
# 61618  NaN            1.0
# 78398  NaN            0.0
# 47803  NaN            1.0
# 69942  NaN            1.0
# 49721  NaN            1.0
#
# [37243 rows x 2 columns]

# %%
import joblib

# %%
joblib.dump(dt_obj,'Customer Type.lb')
# Out:
# ['Customer Type.lb']

# %%
model=joblib.load('Customer Type.lb')

# %%
model.predict(x_test)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %% [markdown]
# word of the crowed
# voting    (algo differ)   final result
# bagging   (algo same)   horizontal
# bousting  (vertical)      adaboost,  xgboost,  gradient
# staking   multipal result to datafream then apply algo

# %%
from sklearn.ensemble import RandomForestClassifier , RandomForestRegressor

# %%
obj = RandomForestClassifier()

# %%
obj.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
obj.fit(x_train,y_train)
# Out:
# d:\CRT\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
RandomForestClassifier(n_estimators=150,max_depth=2,min_samples_leaf=1,oob_score=True)obj=
# Out:
#   Cell In[94], line 1
#     RandomForestClassifier(n_estimators=150,max_depth=2,min_samples_leaf=1,oob_score=True)obj=
#                                                                                           ^
# SyntaxError: invalid syntax

# %%
obj.fit(x_train,y_train)
# Out:
# d:\CRT\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(max_depth=2, n_estimators=150, oob_score=True)

# %%
print("Traning score :",obj.score(x_train,y_train))
print("Traning score :",obj.score(x_test,y_test))
# Out:
# Traning score : 0.8163336838415702
# Traning score : 0.8206913222141649

# %%
obj_with_parameter=RandomForestClassifier(n_estimators=150,max_depth=2,min_samples_leaf=1,oob_score=True)

# %%
obj_with_parameter.fit(x_train,y_train)
# Out:
# d:\CRT\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(max_depth=2, n_estimators=150, oob_score=True)

# %%
print("Traning score :",obj_with_parameter.score(x_train,y_train))
print("Traning score :",obj_with_parameter.score(x_test,y_test))
# Out:
# Traning score : 0.8163336838415702
# Traning score : 0.8206913222141649

# %%
pred =obj_with_parameter.predict(x_test)
pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
from sklearn.ensemble import AdaBoostClassifier , AdaBoostRegressor

# %%
obj2=AdaBoostClassifier()

# %%
obj2.fit(x_train,y_train)
# Out:
# d:\CRT\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# d:\CRT\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# AdaBoostClassifier()

# %%
print("Traning score :",obj2.score(x_train,y_train))
print("Traning score :",obj2.score(x_test,y_test))
# Out:
# Traning score : 0.9069702793188054
# Traning score : 0.9074208363548465

# %%
pred=obj2.predict(x_test)
pred
# Out:
# array([1, 1, 1, ..., 0, 1, 1], dtype=int64)

# %%
obj_with_parameter=AdaBoostClassifier(n_estimators=100,learning_rate=1.0,)

# %%
obj_with_parameter=AdaBoostClassifier()

# %%
obj_with_parameter
# Out:
# AdaBoostClassifier()

# %%
obj_with_parameter.fit(x_train,y_train)
# Out:
# d:\CRT\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# d:\CRT\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# AdaBoostClassifier()

# %%
print("Traning score :",obj_with_parameter.score(x_train,y_train))
print("Traning score :",obj_with_parameter.score(x_test,y_test))
# Out:
# Traning score : 0.9069702793188054
# Traning score : 0.9074208363548465

# %%
pred=obj_with_parameter.predict(x_test)
pred
# Out:
# array([1, 1, 1, ..., 0, 1, 1], dtype=int64)

# %%
from sklearn.ensemble import GradientBoostingRegressor,GradientBoostingClassifier

# %%
obj=GradientBoostingRegressor()

# %%
obj.fit(x_train,y_train)
# Out:
# d:\CRT\Lib\site-packages\sklearn\ensemble\_gb.py:668: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# GradientBoostingRegressor()

# %%
print("Traning score :",obj.score(x_train,y_train))
print("Traning score :",obj.score(x_test,y_test))
# Out:
# Traning score : 0.6144464517838689
# Traning score : 0.6124358778088068

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
obj=GradientBoostingClassifier()

# %%
obj.fit(x_train,y_train)
# Out:
# d:\CRT\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoostingClassifier()

# %%
print("Traning score :",obj.score(x_train,y_train))
print("Traning score :",obj.score(x_test,y_test))
# Out:
# Traning score : 0.9286534440455902
# Traning score : 0.929369108049311
